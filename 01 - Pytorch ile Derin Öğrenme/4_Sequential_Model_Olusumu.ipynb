# %% [markdown]
# ### Kütüphaneler

# %%
import torch
import torch.nn as nn 
import torch.optim as optim  
import torchvision.transforms as transforms 
import torchvision
import os
import pandas as pd
from torch.utils.data import (Dataset,DataLoader) 
from skimage import io
import time

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Veriyi Dahil Etme

# %%
class veri(Dataset):
    def __init__(self, csv_file, root_dir, transform=None):
        self.annotations = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        
    def __len__(self):
        return len(self.annotations)
    
    def __getitem__(self, index):
        img_path = os.path.join(self.root_dir, self.annotations.iloc[index, 0])
        image = io.imread(img_path)
        y_label = torch.tensor(int(self.annotations.iloc[index, 1]))
        
        if self.transform:
            image = self.transform(image)
            
        return (image, y_label)

# %% [markdown]
# ### Veriyi Hazırlama

# %%
dataset = veri(csv_file = r"f113.csv",
              root_dir = r"f1_classification",
              transform = transforms.Compose([
                  transforms.ToTensor(),
                  transforms.Resize(size = (28, 28)),
                  transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]))

# %% [markdown]
# ### Veri Ön İşleme

# %%
train_set,  test_set = torch.utils.data.random_split(dataset, [200,79]) 
# 201 tanesi eğitim 79 tanesi test olsun istedik 280 tane verisetimiz var 0'dan başlıyor saymaya
train_loader = DataLoader(dataset=train_set, batch_size=1, shuffle=False)
test_loader = DataLoader(dataset=test_set, batch_size=1, shuffle=False)
# shuffle True olursa veri setimiz karıştırılır.

# %% [markdown]
# ### Model Mimarisini Oluşturma

# %%
model = nn.Sequential(
    
    nn.Conv2d(in_channels = 3, out_channels = 4, kernel_size = (5, 5)),
    nn.ReLU(),
    nn.MaxPool2d(kernel_size = (2, 2)),
    
    nn.Conv2d(in_channels = 4, out_channels = 8, kernel_size = (3, 3)),
    nn.ReLU(),
    nn.MaxPool2d(kernel_size = (2, 2)),
    
    nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = (2, 2)),
    nn.ReLU(),
    nn.MaxPool2d(kernel_size = (2, 2)),
    
    nn.Conv2d(in_channels = 16, out_channels = 32, kernel_size = (2, 2)),
    nn.ReLU(),

    nn.Flatten(),
    
    nn.Linear(in_features = 32, out_features = 50),
    nn.ReLU(),
    
    nn.Linear(in_features = 50, out_features = 50),
    nn.ReLU(),
    
    nn.Linear(in_features = 50, out_features = 100),
    nn.ReLU(),
    
    nn.Linear(in_features = 100, out_features = 4),
    
)

# %% [markdown]
# ### Sequential Modelin Eğitimi ve Testi

# %%
start = time.time()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

error = torch.nn.CrossEntropyLoss()

epoch = 5

for i in range(epoch):
    for images, label in train_loader:
        
        optimizer.zero_grad()
        
        tahmin = model(images)
        
        loss = error(tahmin, label)
        
        loss.backward()
        
        optimizer.step()
        
        print(f"Epoch [{i+1}/{epoch}], loss: {loss.item():.4f}")
        
end = time.time()
print("Süre: ", end - start)
# Out:
# Epoch [1/5], loss: 1.4608
# Epoch [1/5], loss: 1.4648
# Epoch [1/5], loss: 1.3796
# Epoch [1/5], loss: 1.2842
# Epoch [1/5], loss: 1.4539
# Epoch [1/5], loss: 1.4410
# Epoch [1/5], loss: 1.3792
# Epoch [1/5], loss: 1.2897
# Epoch [1/5], loss: 1.4382
# Epoch [1/5], loss: 1.4516
# Epoch [1/5], loss: 1.2912
# Epoch [1/5], loss: 1.4343
# Epoch [1/5], loss: 1.4457
# Epoch [1/5], loss: 1.4306
# Epoch [1/5], loss: 1.2917
# Epoch [1/5], loss: 1.4431
# Epoch [1/5], loss: 1.4234
# Epoch [1/5], loss: 1.4385
# Epoch [1/5], loss: 1.4349
# Epoch [1/5], loss: 1.4108
# Epoch [1/5], loss: 1.4262
# Epoch [1/5], loss: 1.2974
# Epoch [1/5], loss: 1.4166
# Epoch [1/5], loss: 1.4172
# Epoch [1/5], loss: 1.4138
# Epoch [1/5], loss: 1.4105
# Epoch [1/5], loss: 1.4264
# Epoch [1/5], loss: 1.4121
# Epoch [1/5], loss: 1.4112
# Epoch [1/5], loss: 1.4288
# Epoch [1/5], loss: 1.4286
# Epoch [1/5], loss: 1.4040
# Epoch [1/5], loss: 1.4254
# Epoch [1/5], loss: 1.3297
# Epoch [1/5], loss: 1.3980
# Epoch [1/5], loss: 1.4185
# Epoch [1/5], loss: 1.4164
# Epoch [1/5], loss: 1.3965
# Epoch [1/5], loss: 1.4092
# Epoch [1/5], loss: 1.3958
# Epoch [1/5], loss: 1.4002
# Epoch [1/5], loss: 1.3918
# Epoch [1/5], loss: 1.4005
# Epoch [1/5], loss: 1.3941
# Epoch [1/5], loss: 1.3701
# Epoch [1/5], loss: 1.3980
# Epoch [1/5], loss: 1.3848
# Epoch [1/5], loss: 1.3782
# Epoch [1/5], loss: 1.3951
# Epoch [1/5], loss: 1.3898
# Epoch [1/5], loss: 1.3884
# Epoch [1/5], loss: 1.3918
# Epoch [1/5], loss: 1.3839
# Epoch [1/5], loss: 1.3876
# Epoch [1/5], loss: 1.3953
# Epoch [1/5], loss: 1.3965
# Epoch [1/5], loss: 1.3762
# Epoch [1/5], loss: 1.3812
# Epoch [1/5], loss: 1.3999
# Epoch [1/5], loss: 1.3946
# Epoch [1/5], loss: 1.3769
# Epoch [1/5], loss: 1.3739
# Epoch [1/5], loss: 1.4064
# Epoch [1/5], loss: 1.3736
# Epoch [1/5], loss: 1.3736
# Epoch [1/5], loss: 1.3661
# Epoch [1/5], loss: 1.4114
# Epoch [1/5], loss: 1.4104
# Epoch [1/5], loss: 1.3601
# Epoch [1/5], loss: 1.3695
# Epoch [1/5], loss: 1.3683
# Epoch [1/5], loss: 1.3660
# Epoch [1/5], loss: 1.4226
# Epoch [1/5], loss: 1.4273
# Epoch [1/5], loss: 1.4108
# Epoch [1/5], loss: 1.4111
# Epoch [1/5], loss: 1.3569
# Epoch [1/5], loss: 1.3576
# Epoch [1/5], loss: 1.3540
# Epoch [1/5], loss: 1.4326
# Epoch [1/5], loss: 1.3548
# Epoch [1/5], loss: 1.3522
# Epoch [1/5], loss: 1.3496
# Epoch [1/5], loss: 1.3512
# Epoch [1/5], loss: 1.3453
# Epoch [1/5], loss: 1.3476
# Epoch [1/5], loss: 1.3435
# Epoch [1/5], loss: 1.4233
# Epoch [1/5], loss: 1.4549
# Epoch [1/5], loss: 1.4584
# Epoch [1/5], loss: 1.4526
# Epoch [1/5], loss: 1.3331
# Epoch [1/5], loss: 1.3318
# Epoch [1/5], loss: 1.3400
# Epoch [1/5], loss: 1.3256
# Epoch [1/5], loss: 1.3405
# Epoch [1/5], loss: 1.4459
# Epoch [1/5], loss: 1.4457
# Epoch [1/5], loss: 1.3164
# Epoch [1/5], loss: 1.3426
# Epoch [1/5], loss: 1.3418
# Epoch [1/5], loss: 1.3111
# Epoch [1/5], loss: 1.4365
# Epoch [1/5], loss: 1.4366
# Epoch [1/5], loss: 1.3059
# Epoch [1/5], loss: 1.3041
# Epoch [1/5], loss: 1.3009
# Epoch [1/5], loss: 1.2953
# Epoch [1/5], loss: 1.3394
# Epoch [1/5], loss: 1.2832
# Epoch [1/5], loss: 1.4312
# Epoch [1/5], loss: 1.5210
# Epoch [1/5], loss: 1.2680
# Epoch [1/5], loss: 1.3440
# Epoch [1/5], loss: 1.2602
# Epoch [1/5], loss: 1.2550
# Epoch [1/5], loss: 1.3410
# Epoch [1/5], loss: 1.5464
# Epoch [1/5], loss: 1.5489
# Epoch [1/5], loss: 1.5484
# Epoch [1/5], loss: 1.5442
# Epoch [1/5], loss: 1.4597
# Epoch [1/5], loss: 1.4579
# Epoch [1/5], loss: 1.4537
# Epoch [1/5], loss: 1.5262
# Epoch [1/5], loss: 1.3580
# Epoch [1/5], loss: 1.5144
# Epoch [1/5], loss: 1.5087
# Epoch [1/5], loss: 1.5004
# Epoch [1/5], loss: 1.2640
# Epoch [1/5], loss: 1.4332
# Epoch [1/5], loss: 1.4829
# Epoch [1/5], loss: 1.4733
# Epoch [1/5], loss: 1.2809
# Epoch [1/5], loss: 1.2807
# Epoch [1/5], loss: 1.4240
# Epoch [1/5], loss: 1.4239
# Epoch [1/5], loss: 1.4544
# Epoch [1/5], loss: 1.4183
# Epoch [1/5], loss: 1.2877
# Epoch [1/5], loss: 1.4105
# Epoch [1/5], loss: 1.4097
# Epoch [1/5], loss: 1.2920
# Epoch [1/5], loss: 1.4023
# Epoch [1/5], loss: 1.3975
# Epoch [1/5], loss: 1.4395
# Epoch [1/5], loss: 1.2957
# Epoch [1/5], loss: 1.2951
# Epoch [1/5], loss: 1.2940
# Epoch [1/5], loss: 1.4404
# Epoch [1/5], loss: 1.2895
# Epoch [1/5], loss: 1.4423
# Epoch [1/5], loss: 1.3862
# Epoch [1/5], loss: 1.4402
# Epoch [1/5], loss: 1.3801
# Epoch [1/5], loss: 1.3797
# Epoch [1/5], loss: 1.3780
# Epoch [1/5], loss: 1.4650
# Epoch [1/5], loss: 1.4593
# Epoch [1/5], loss: 1.4575
# Epoch [1/5], loss: 1.4614
# Epoch [1/5], loss: 1.4398
# Epoch [1/5], loss: 1.3624
# Epoch [1/5], loss: 1.3636
# Epoch [1/5], loss: 1.3010
# Epoch [1/5], loss: 1.3543
# Epoch [1/5], loss: 1.4554
# Epoch [1/5], loss: 1.4472
# Epoch [1/5], loss: 1.3458
# Epoch [1/5], loss: 1.4506
# Epoch [1/5], loss: 1.4415
# Epoch [1/5], loss: 1.3164
# Epoch [1/5], loss: 1.4386
# Epoch [1/5], loss: 1.3459
# Epoch [1/5], loss: 1.3421
# Epoch [1/5], loss: 1.3352
# Epoch [1/5], loss: 1.3244
# Epoch [1/5], loss: 1.4611
# Epoch [1/5], loss: 1.4349
# Epoch [1/5], loss: 1.3318
# Epoch [1/5], loss: 1.4380
# Epoch [3/5], loss: 0.9957
# Epoch [3/5], loss: 1.4241
# Epoch [3/5], loss: 0.7939
# Epoch [3/5], loss: 0.4948
# Epoch [3/5], loss: 0.4546
# Epoch [3/5], loss: 1.0177
# Epoch [3/5], loss: 0.3964
# Epoch [3/5], loss: 1.3497
# Epoch [3/5], loss: 1.2264
# Epoch [3/5], loss: 1.0081
# Epoch [3/5], loss: 1.3055
# Epoch [3/5], loss: 0.3404
# Epoch [3/5], loss: 1.5034
# Epoch [3/5], loss: 1.1434
# Epoch [3/5], loss: 0.7297
# Epoch [3/5], loss: 1.8656
# Epoch [3/5], loss: 2.8281
# Epoch [3/5], loss: 0.3357
# Epoch [3/5], loss: 0.3649
# Epoch [3/5], loss: 1.0885
# Epoch [3/5], loss: 0.4049
# Epoch [3/5], loss: 1.3407
# Epoch [3/5], loss: 1.3747
# Epoch [3/5], loss: 1.6644
# Epoch [3/5], loss: 3.0163
# Epoch [3/5], loss: 1.0795
# Epoch [3/5], loss: 1.0749
# Epoch [3/5], loss: 1.3926
# Epoch [3/5], loss: 0.8732
# Epoch [3/5], loss: 0.7728
# Epoch [3/5], loss: 0.9383
# Epoch [3/5], loss: 0.5157
# Epoch [3/5], loss: 0.4419
# Epoch [3/5], loss: 0.8081
# Epoch [3/5], loss: 1.0955
# Epoch [3/5], loss: 1.0034
# Epoch [3/5], loss: 0.7584
# Epoch [3/5], loss: 0.5126
# Epoch [3/5], loss: 0.4088
# Epoch [3/5], loss: 0.3840
# Epoch [3/5], loss: 1.8062
# Epoch [3/5], loss: 1.6849
# Epoch [3/5], loss: 1.0357
# Epoch [3/5], loss: 1.0037
# Epoch [3/5], loss: 0.8381
# Epoch [3/5], loss: 0.9693
# Epoch [3/5], loss: 0.2483
# Epoch [3/5], loss: 2.0074
# Epoch [3/5], loss: 0.7602
# Epoch [3/5], loss: 0.2042
# Epoch [3/5], loss: 0.1929
# Epoch [3/5], loss: 0.9193
# Epoch [3/5], loss: 0.1913
# Epoch [3/5], loss: 0.8295
# Epoch [3/5], loss: 0.5262
# Epoch [3/5], loss: 1.0693
# Epoch [3/5], loss: 1.4041
# Epoch [3/5], loss: 1.7532
# Epoch [3/5], loss: 2.0796
# Epoch [3/5], loss: 0.6710
# Epoch [3/5], loss: 0.9178
# Epoch [3/5], loss: 0.0953
# Epoch [3/5], loss: 0.6650
# Epoch [3/5], loss: 0.0876
# Epoch [3/5], loss: 2.0788
# Epoch [3/5], loss: 1.8494
# Epoch [3/5], loss: 0.6545
# Epoch [3/5], loss: 2.6709
# Epoch [3/5], loss: 2.8945
# Epoch [3/5], loss: 0.4784
# Epoch [3/5], loss: 1.8292
# Epoch [3/5], loss: 1.8635
# Epoch [3/5], loss: 0.6255
# Epoch [3/5], loss: 0.5499
# Epoch [3/5], loss: 0.7593
# Epoch [3/5], loss: 0.4604
# Epoch [3/5], loss: 1.9280
# Epoch [3/5], loss: 0.6678
# Epoch [3/5], loss: 2.0143
# Epoch [3/5], loss: 1.4276
# Epoch [3/5], loss: 0.6372
# Epoch [3/5], loss: 2.1630
# Epoch [3/5], loss: 0.5660
# Epoch [3/5], loss: 0.7374
# Epoch [3/5], loss: 0.3154
# Epoch [3/5], loss: 1.4517
# Epoch [3/5], loss: 1.5074
# Epoch [3/5], loss: 1.4449
# Epoch [3/5], loss: 1.6418
# Epoch [3/5], loss: 1.5557
# Epoch [3/5], loss: 1.4313
# Epoch [3/5], loss: 1.3538
# Epoch [3/5], loss: 1.3881
# Epoch [3/5], loss: 0.3039
# Epoch [3/5], loss: 1.3921
# Epoch [3/5], loss: 1.3800
# Epoch [3/5], loss: 1.3211
# Epoch [3/5], loss: 0.7340
# Epoch [3/5], loss: 1.5820
# Epoch [3/5], loss: 1.2820
# Epoch [3/5], loss: 1.2214
# Epoch [3/5], loss: 0.6795
# Epoch [3/5], loss: 0.7984
# Epoch [3/5], loss: 1.4209
# Epoch [3/5], loss: 1.5406
# Epoch [3/5], loss: 1.1945
# Epoch [3/5], loss: 1.3401
# Epoch [3/5], loss: 0.7865
# Epoch [3/5], loss: 0.4217
# Epoch [3/5], loss: 1.4445
# Epoch [3/5], loss: 0.7608
# Epoch [3/5], loss: 1.3955
# Epoch [3/5], loss: 1.4088
# Epoch [3/5], loss: 1.0551
# Epoch [3/5], loss: 0.7199
# Epoch [3/5], loss: 0.8052
# Epoch [3/5], loss: 0.8442
# Epoch [3/5], loss: 1.1656
# Epoch [3/5], loss: 0.9273
# Epoch [3/5], loss: 0.6658
# Epoch [3/5], loss: 1.9797
# Epoch [3/5], loss: 1.1650
# Epoch [3/5], loss: 1.4781
# Epoch [3/5], loss: 1.7119
# Epoch [3/5], loss: 1.3623
# Epoch [3/5], loss: 2.3290
# Epoch [3/5], loss: 0.5415
# Epoch [3/5], loss: 0.5578
# Epoch [3/5], loss: 0.8417
# Epoch [3/5], loss: 1.0811
# Epoch [3/5], loss: 1.0572
# Epoch [3/5], loss: 1.1422
# Epoch [3/5], loss: 0.8403
# Epoch [3/5], loss: 1.0327
# Epoch [3/5], loss: 0.5617
# Epoch [3/5], loss: 0.4566
# Epoch [3/5], loss: 1.0268
# Epoch [3/5], loss: 1.2466
# Epoch [3/5], loss: 0.4279
# Epoch [3/5], loss: 1.0924
# Epoch [3/5], loss: 0.4004
# Epoch [3/5], loss: 1.0665
# Epoch [3/5], loss: 1.2720
# Epoch [3/5], loss: 1.2552
# Epoch [3/5], loss: 0.9430
# Epoch [3/5], loss: 1.2337
# Epoch [3/5], loss: 0.4239
# Epoch [3/5], loss: 1.0195
# Epoch [3/5], loss: 0.4704
# Epoch [3/5], loss: 0.4282
# Epoch [3/5], loss: 0.4858
# Epoch [3/5], loss: 1.1077
# Epoch [3/5], loss: 0.5415
# Epoch [3/5], loss: 0.4576
# Epoch [3/5], loss: 0.8447
# Epoch [3/5], loss: 0.4096
# Epoch [3/5], loss: 0.8204
# Epoch [3/5], loss: 0.5108
# Epoch [3/5], loss: 1.0626
# Epoch [3/5], loss: 0.9626
# Epoch [3/5], loss: 1.5463
# Epoch [3/5], loss: 2.8515
# Epoch [3/5], loss: 0.9578
# Epoch [3/5], loss: 1.0319
# Epoch [3/5], loss: 0.9603
# Epoch [3/5], loss: 0.3237
# Epoch [3/5], loss: 0.9538
# Epoch [3/5], loss: 0.3177
# Epoch [4/5], loss: 0.5103
# Epoch [4/5], loss: 0.8620
# Epoch [4/5], loss: 1.0524
# Epoch [4/5], loss: 0.5048
# Epoch [4/5], loss: 1.0440
# Epoch [4/5], loss: 0.4887
# Epoch [4/5], loss: 0.7644
# Epoch [4/5], loss: 1.0072
# Epoch [4/5], loss: 1.0088
# Epoch [4/5], loss: 0.8476
# Epoch [4/5], loss: 1.1092
# Epoch [4/5], loss: 0.5407
# Epoch [4/5], loss: 0.7863
# Epoch [4/5], loss: 0.5622
# Epoch [4/5], loss: 0.5349
# Epoch [4/5], loss: 0.5714
# Epoch [4/5], loss: 0.9731
# Epoch [4/5], loss: 0.6161
# Epoch [4/5], loss: 0.5419
# Epoch [4/5], loss: 0.7650
# Epoch [4/5], loss: 0.4720
# Epoch [4/5], loss: 0.7625
# Epoch [4/5], loss: 0.6982
# Epoch [4/5], loss: 0.8531
# Epoch [4/5], loss: 0.7342
# Epoch [4/5], loss: 1.3581
# Epoch [4/5], loss: 1.1130
# Epoch [4/5], loss: 0.7615
# Epoch [4/5], loss: 1.0205
# Epoch [4/5], loss: 0.7980
# Epoch [4/5], loss: 0.2957
# Epoch [4/5], loss: 0.8078
# Epoch [4/5], loss: 0.2676
# Epoch [5/5], loss: 0.2992
# Epoch [5/5], loss: 0.7534
# Epoch [5/5], loss: 2.1102
# Epoch [5/5], loss: 1.3658
# Epoch [5/5], loss: 0.5235
# Epoch [5/5], loss: 2.3061
# Epoch [5/5], loss: 0.8885
# Epoch [5/5], loss: 2.4461
# Epoch [5/5], loss: 0.3138
# Epoch [5/5], loss: 0.5199
# Epoch [5/5], loss: 1.1732
# Epoch [5/5], loss: 0.9581
# Epoch [5/5], loss: 0.4820
# Epoch [5/5], loss: 0.3022
# Epoch [5/5], loss: 0.9195
# Epoch [5/5], loss: 0.4853
# Epoch [5/5], loss: 2.7059
# Epoch [5/5], loss: 0.5897
# Epoch [5/5], loss: 0.7307
# Epoch [5/5], loss: 1.0173
# Epoch [5/5], loss: 0.3738
# Epoch [5/5], loss: 0.8395
# Epoch [5/5], loss: 1.4928
# Epoch [5/5], loss: 1.2795
# Epoch [5/5], loss: 0.5944
# Epoch [5/5], loss: 0.4340
# Epoch [5/5], loss: 0.3656
# Epoch [5/5], loss: 1.6125
# Epoch [5/5], loss: 1.0862
# Epoch [5/5], loss: 0.3581
# Epoch [5/5], loss: 0.3474
# Epoch [5/5], loss: 1.0407
# Epoch [5/5], loss: 0.4880
# Epoch [5/5], loss: 0.9556
# Epoch [5/5], loss: 0.5194
# Epoch [5/5], loss: 0.2833
# Epoch [5/5], loss: 0.2756
# Epoch [5/5], loss: 0.4805
# Epoch [5/5], loss: 0.2502
# Epoch [5/5], loss: 0.5596
# Epoch [5/5], loss: 1.2429
# Epoch [5/5], loss: 0.4528
# Epoch [5/5], loss: 1.0339
# Epoch [5/5], loss: 0.5314
# Epoch [5/5], loss: 0.9281
# Epoch [5/5], loss: 1.1030
# Epoch [5/5], loss: 0.3711
# Epoch [5/5], loss: 1.8823
# Epoch [5/5], loss: 2.5435
# Epoch [5/5], loss: 0.1708
# Epoch [5/5], loss: 0.2214
# Epoch [5/5], loss: 1.0804
# Epoch [5/5], loss: 0.5926
# Epoch [5/5], loss: 1.3932
# Epoch [5/5], loss: 0.9070
# Epoch [5/5], loss: 2.3867
# Epoch [5/5], loss: 3.1122
# Epoch [5/5], loss: 0.9048
# Epoch [5/5], loss: 0.7102
# Epoch [5/5], loss: 0.9666
# Epoch [5/5], loss: 0.8955
# Epoch [5/5], loss: 0.8809
# Epoch [5/5], loss: 0.6604
# Epoch [5/5], loss: 0.2986
# Epoch [5/5], loss: 0.2435
# Epoch [5/5], loss: 0.7768
# Epoch [5/5], loss: 0.8134
# Epoch [5/5], loss: 0.8592
# Epoch [5/5], loss: 0.7667
# Epoch [5/5], loss: 0.3508
# Epoch [5/5], loss: 0.3015
# Epoch [5/5], loss: 0.2486
# Epoch [5/5], loss: 1.2818
# Epoch [5/5], loss: 1.3668
# Epoch [5/5], loss: 0.8607
# Epoch [5/5], loss: 0.7553
# Epoch [5/5], loss: 0.8631
# Epoch [5/5], loss: 0.9402
# Epoch [5/5], loss: 0.1899
# Epoch [5/5], loss: 2.2637
# Epoch [5/5], loss: 0.7927
# Epoch [5/5], loss: 0.1524
# Epoch [5/5], loss: 0.1445
# Epoch [5/5], loss: 0.9212
# Epoch [5/5], loss: 0.1662
# Epoch [5/5], loss: 0.9056
# Epoch [5/5], loss: 0.6575
# Epoch [5/5], loss: 0.9239
# Epoch [5/5], loss: 0.9596
# Epoch [5/5], loss: 1.0447
# Epoch [5/5], loss: 1.5799
# Epoch [5/5], loss: 0.7810
# Epoch [5/5], loss: 1.2635
# Epoch [5/5], loss: 0.1127
# Epoch [5/5], loss: 0.6940
# Epoch [5/5], loss: 0.1083
# Epoch [5/5], loss: 1.4009
# Epoch [5/5], loss: 1.3668
# Epoch [5/5], loss: 0.7344
# Epoch [5/5], loss: 1.9629
# Epoch [5/5], loss: 2.6119
# Epoch [5/5], loss: 0.5912
# Epoch [5/5], loss: 1.2351
# Epoch [5/5], loss: 1.4798
# Epoch [5/5], loss: 0.6962
# Epoch [5/5], loss: 0.6353
# Epoch [5/5], loss: 0.8669
# Epoch [5/5], loss: 0.5413
# Epoch [5/5], loss: 0.5175
# Epoch [5/5], loss: 0.8861
# Epoch [5/5], loss: 1.6245
# Epoch [5/5], loss: 1.1336
# Epoch [5/5], loss: 0.7697
# Epoch [5/5], loss: 1.5689
# Epoch [5/5], loss: 0.6616
# Epoch [5/5], loss: 0.9541
# Epoch [5/5], loss: 0.1620
# Epoch [5/5], loss: 1.3866
# Epoch [5/5], loss: 1.2067
# Epoch [5/5], loss: 1.5569
# Epoch [5/5], loss: 1.2201
# Epoch [5/5], loss: 1.0884
# Epoch [5/5], loss: 0.9025
# Epoch [5/5], loss: 1.6697
# Epoch [5/5], loss: 1.0894
# Epoch [5/5], loss: 0.2094
# Epoch [5/5], loss: 1.1136
# Epoch [5/5], loss: 1.1112
# Epoch [5/5], loss: 1.0167
# Epoch [5/5], loss: 0.5384
# Epoch [5/5], loss: 0.8637
# Epoch [5/5], loss: 0.9477
# Epoch [5/5], loss: 0.9365
# Epoch [5/5], loss: 0.5661
# Epoch [5/5], loss: 0.6088
# Epoch [5/5], loss: 1.2241
# Epoch [5/5], loss: 1.0454
# Epoch [5/5], loss: 0.8255
# Epoch [5/5], loss: 0.8301
# Epoch [5/5], loss: 0.6721
# Epoch [5/5], loss: 0.4251
# Epoch [5/5], loss: 1.9790
# Epoch [5/5], loss: 0.6858
# Epoch [5/5], loss: 1.0136
# Epoch [5/5], loss: 0.9185
# Epoch [5/5], loss: 0.7580
# Epoch [5/5], loss: 0.6863
# Epoch [5/5], loss: 0.7110
# Epoch [5/5], loss: 0.7278
# Epoch [5/5], loss: 0.9503
# Epoch [5/5], loss: 0.9218
# Epoch [5/5], loss: 0.6187
# Epoch [5/5], loss: 2.0637
# Epoch [5/5], loss: 1.0583
# Epoch [5/5], loss: 0.7370
# Epoch [5/5], loss: 1.3322
# Epoch [5/5], loss: 0.7842
# Epoch [5/5], loss: 2.0188
# Epoch [5/5], loss: 0.5097
# Epoch [5/5], loss: 0.5106
# Epoch [5/5], loss: 0.8560
# Epoch [5/5], loss: 0.8842
# Epoch [5/5], loss: 0.9656
# Epoch [5/5], loss: 0.7531
# Epoch [5/5], loss: 0.7456
# Epoch [5/5], loss: 0.7708
# Epoch [5/5], loss: 0.5013
# Epoch [5/5], loss: 0.4130
# Epoch [5/5], loss: 0.7469
# Epoch [5/5], loss: 1.2054
# Epoch [5/5], loss: 0.3895
# Epoch [5/5], loss: 1.0176
# Epoch [5/5], loss: 0.3793
# Epoch [5/5], loss: 0.6222
# Epoch [5/5], loss: 1.2401
# Epoch [5/5], loss: 1.1731
# Epoch [5/5], loss: 0.7682
# Epoch [5/5], loss: 1.0899
# Epoch [5/5], loss: 0.5195
# Epoch [5/5], loss: 0.6994
# Epoch [5/5], loss: 0.6253
# Epoch [5/5], loss: 0.4342
# Epoch [5/5], loss: 0.5969
# Epoch [5/5], loss: 1.0617
# Epoch [5/5], loss: 0.6925
# Epoch [5/5], loss: 0.5734
# Epoch [5/5], loss: 0.7024
# Epoch [5/5], loss: 0.4913
# Epoch [5/5], loss: 0.7090
# Epoch [5/5], loss: 0.6908
# Epoch [5/5], loss: 0.7400
# Epoch [5/5], loss: 0.7786
# Epoch [5/5], loss: 1.6592
# Epoch [5/5], loss: 1.0074
# Epoch [5/5], loss: 0.7905
# Epoch [5/5], loss: 0.8439
# Epoch [5/5], loss: 0.8011
# Epoch [5/5], loss: 0.2059
# Epoch [5/5], loss: 0.8124
# Epoch [5/5], loss: 0.1804
# Süre:  74.77918004989624

# %% [markdown]
# ### Model Testi

# %%
def dogruluk(loader, model):
    num_correct = 0
    num_samples = 0
    model.eval()
    
    with torch.no_grad():
        for x, y in loader:
            tahmin = model(x)
            _, pred = tahmin.max(1)
            num_correct += (pred==y).sum()
            num_samples += pred.size(0)
        print(f"Got {num_correct} / {num_samples} with accuracy {float(num_correct) / float(num_samples) * 100:.2f}")
        model.train()

# %%
print("Train Doğruluk: ")
dogruluk(train_loader, model)
print("Test Doğruluk: ")
dogruluk(test_loader, model)
# Out:
# Train Doğruluk:
# Got 101 / 200 with accuracy 50.50
# Test Doğruluk:
# Got 35 / 79 with accuracy 44.30
